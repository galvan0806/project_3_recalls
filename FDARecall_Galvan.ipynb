# %%
import requests
import pandas as pd
import plotly.express as px
from pymongo import MongoClient
from datetime import datetime

# Define the API endpoint and parameters
url = "https://api.fda.gov/food/enforcement.json?search=report_date:[20200101+TO+20241005]&limit=500"

# Send a GET request to the API
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    recalls = data.get('results', [])
    recall_df = pd.DataFrame(recalls)

    clean_df = recall_df.rename(columns={
        "status": "Status", 
        "city": "City",
        "state": "State",
        "country":"Country",
        "classification":"Classification",
        "openfda":"Open FDA",
        "product_type":"Product Type",
        "event_id":"Event ID",
        "recalling_firm":"Recalling Firm",
        "address_1":"Address 1",
        "address_2":"Address 2",
        "postal_code":"Postal Code",
        "voluntary_mandated":"Voluntary Mandated",
        "initial_firm_notification":"Initial Firm Notification",
        "distribution_pattern":"Distribution Pattern",
        "recall_number":"Recall Number",
        "product_description":"Product Description",
        "product_quantity":"Product Quantity",
        "reason_for_recall":"Reason for Recall",
        "recall_initiation_date":"Recall Initiation Date",
        "center_classification_date":"Center Classification Date",
        "termination_date":"Termination Date",
        "report_date":"Report Date",
        "code_info":"Code Info",
        "more_code_info":"More Code Info",
    })

    # Convert DataFrame to dictionary format for MongoDB
    recall_records = clean_df.to_dict("records")

    # Connect to MongoDB
    client = MongoClient('mongodb://localhost:27017/')  # Or use your MongoDB URI
    db = client['fda_recall_data']  # Database name
    collection = db['recalls']  # Collection name

    # Insert modified data into MongoDB
    collection.insert_many(recall_records)

    # Example: Query data back from MongoDB
    recalls_from_db = list(collection.find())

    # Convert back to DataFrame if needed
    db_df = pd.DataFrame(recalls_from_db)

    # Close the connection
    client.close()
else:
    print(f"Failed to retrieve data: {response.status_code}")

# %%
recalls_from_db
# Out:
# [{'_id': ObjectId('67105b498e02bfea25a69cb4'),
#   'Status': 'Terminated',
#   'City': 'Rancho Dominguez',
#   'State': 'CA',
#   'Country': 'United States',
#   'Classification': 'Class III',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '85253',
#   'Recalling Firm': 'Organic By Nature, Inc.',
#   'Address 1': '2610 Homestead Pl',
#   'Address 2': 'N/A',
#   'Postal Code': '90220-5610',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'nationwide, Canada and Netherlands',
#   'Recall Number': 'F-0904-2020',
#   'Product Description': 'Pure Planet Organic Parasite Cleanse;  Net Wt. 174g Glass Jar;  Finished Product Item # 52700    Manufactured and Distributed by:  Pure Planet,  Rancho Dominguez, CA',
#   'Product Quantity': 'xx',
#   'Reason for Recall': 'Firm was notified by supplier that Organic Ground Flaxseed powder was under recall by manufacturer due to unapproved herbicide - Haloxyfop',
#   'Recall Initiation Date': '20200224',
#   'Center Classification Date': '20200413',
#   'Termination Date': '20210202',
#   'Report Date': '20200401',
#   'Code Info': 'Lot codes: 72746',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cb5'),
#   'Status': 'Terminated',
#   'City': 'Brooklyn',
#   'State': 'NY',
#   'Country': 'United States',
#   'Classification': 'Class III',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '85364',
#   'Recalling Firm': 'Rong Shing Trading NY Inc',
#   'Address 1': '47 Bridgewater St # 57',
#   'Address 2': 'N/A',
#   'Postal Code': '11222-3820',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'Unknown',
#   'Recall Number': 'F-0921-2020',
#   'Product Description': 'XinXing Dried Plum, Net Wt. 5.3 oz.(150g)',
#   'Product Quantity': 'unknown',
#   'Reason for Recall': 'Product contains dried peaches, but front labeling of product stated dried plums',
#   'Recall Initiation Date': '20200401',
#   'Center Classification Date': '20200424',
#   'Termination Date': '20210318',
#   'Report Date': '20200506',
#   'Code Info': 'UPC CODE: 6868978724496  BEST BEFORE: 11/15/2021',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cb6'),
#   'Status': 'Terminated',
#   'City': 'Monterey',
#   'State': 'CA',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '89381',
#   'Recalling Firm': 'Dole Fresh Vegetables Inc',
#   'Address 1': '2959 Salinas Hwy',
#   'Address 2': '',
#   'Postal Code': '93940-6400',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Telephone',
#   'Distribution Pattern': 'Canada: AB, BC, NB, ON, QC, Sk; United States: AL, AZ, CA, CO, CT, FL, GA, HI, IA, ID, IL, IN, KS, KY, LA, MA, MD, MI, MN, MO, MS, NC, ND, NE, NV, NY, OH, OK, OR, PA, SC, TN, TX, UT, VA, WA, WI',
#   'Recall Number': 'F-0757-2022',
#   'Product Description': 'Marketside 12oz Classic Salad  UPC:6-81131-32894-4  SKU: 3107',
#   'Product Quantity': '',
#   'Reason for Recall': 'Harvest equipment used in harvesting raw iceberg lettuce was tested by  Dole and found to contain Listeria monocytogenes.',
#   'Recall Initiation Date': '20220106',
#   'Center Classification Date': '20220222',
#   'Termination Date': '20220322',
#   'Report Date': '20220302',
#   'Code Info': 'Product codes beginning with B - Best by Dates of December 23, 2021 through January 8, 2022.',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cb7'),
#   'Status': 'Terminated',
#   'City': 'Lovell',
#   'State': 'WY',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '90158',
#   'Recalling Firm': 'Queen Bee Gardens, LLC',
#   'Address 1': '262 E Main St',
#   'Address 2': 'N/A',
#   'Postal Code': '82431-2102',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Press Release',
#   'Distribution Pattern': 'Ten retail locations owned by Queen Bee in CO, NM, WY and nationwide via internet sales.',
#   'Recall Number': 'F-1472-2022',
#   'Product Description': 'Honey Caramels Blue Raspberry. Product available in 5.87 oz. bag, 1 lb. bag, 3 lb. bag, 6 lb. bag. PLU Code for 5.87 oz. bag: 788394 12675 8.',
#   'Product Quantity': '171 pieces',
#   'Reason for Recall': 'Products may potentially contain one or more of the following undeclared tree nuts: Pecans, Almonds, Coconut, Macadamia Nuts, & Walnuts.',
#   'Recall Initiation Date': '20220428',
#   'Center Classification Date': '20220719',
#   'Termination Date': '20230117',
#   'Report Date': '20220727',
#   'Code Info': 'None',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cb8'),
#   'Status': 'Ongoing',
#   'City': 'Sioux City',
#   'State': 'IA',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '94571',
#   'Recalling Firm': 'Palmer & Company',
#   'Address 1': '311 Bluff St',
#   'Address 2': '',
#   'Postal Code': '51103-5401',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'E-Mail',
#   'Distribution Pattern': 'Nationwide United States and Canada',
#   'Recall Number': 'F-1671-2024',
#   'Product Description': '1. Palmer Candy Drizzled Caramel Corn, Item 19271, Net Wt. 16/5oz tubs, UPC 77343 19271 2. Meijer Drizzled Caramel Popcorn Snack Bowl, Net Wt. 12oz, UPC 60236 18830, 8/12oz case',
#   'Product Quantity': '',
#   'Reason for Recall': 'Potential salmonella contamination',
#   'Recall Initiation Date': '20240503',
#   'Center Classification Date': '20240806',
#   'Termination Date': nan,
#   'Report Date': '20240814',
#   'Code Info': '1. Best by date: 1/22/25 2. Best by date: 1/22/25',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cb9'),
#   'Status': 'Terminated',
#   'City': 'Nof Ha-Galil',
#   'State': '',
#   'Country': 'Israel',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '90105',
#   'Recalling Firm': 'ELITE CONFECTIONERY LTD',
#   'Address 1': 'Nazareth-Ilit',
#   'Address 2': "5, Gilbo'A",
#   'Postal Code': 'N/A',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'Distributed in the US nationwide',
#   'Recall Number': 'F-1233-2022',
#   'Product Description': 'ELITE MILK CHOCOLATE COATED RICE CAKES  UPC:815871011884\tNET WT 2.47OZ (70 g)',
#   'Product Quantity': 'unknown',
#   'Reason for Recall': 'Potential contamination with Salmonella',
#   'Recall Initiation Date': '20220428',
#   'Center Classification Date': '20220604',
#   'Termination Date': '20221103',
#   'Report Date': '20220615',
#   'Code Info': 'All lots',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cba'),
#   'Status': 'Ongoing',
#   'City': 'San Luis',
#   'State': 'AZ',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '93920',
#   'Recalling Firm': 'HandNatural',
#   'Address 1': '874 S Main St',
#   'Address 2': '',
#   'Postal Code': '85349-7500',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'E-Mail',
#   'Distribution Pattern': 'Firm is  100% internet sales. Distribution is unknown at this time.',
#   'Recall Number': 'F-1170-2024',
#   'Product Description': 'H&NATURAL 2 PACK! BRAZIL SEED 60 PIECES, PURE NATURAL SEMILLA DE BRASIL FOR 60 DAYS, 5 GRAMS PER BOX, 2 BLACK BOXES.',
#   'Product Quantity': '',
#   'Reason for Recall': 'Product recalled due to the presence of yellow oleander and its components in the product.',
#   'Recall Initiation Date': '20240209',
#   'Center Classification Date': '20240416',
#   'Termination Date': nan,
#   'Report Date': '20240424',
#   'Code Info': 'No Lot code on label. Expiration date listed as 05/24 and 03/24.',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cbb'),
#   'Status': 'Terminated',
#   'City': 'Dayton',
#   'State': 'OH',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '92726',
#   'Recalling Firm': 'Cassanos Inc',
#   'Address 1': '1700 E Stroop Rd',
#   'Address 2': 'N/A',
#   'Postal Code': '45429-5040',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'Distributed to: CO, FL, IN, IL, KY, MI, OH, PA, WV',
#   'Recall Number': 'F-1354-2023',
#   'Product Description': 'San Marco Premium Dough on Parchment: packaged as 8in, 14in',
#   'Product Quantity': '24575 cases total',
#   'Reason for Recall': 'Undeclared Allergen - Soy Flour',
#   'Recall Initiation Date': '20230718',
#   'Center Classification Date': '20230802',
#   'Termination Date': '20230927',
#   'Report Date': '20230809',
#   'Code Info': 'Lot: 159, 186 Expiration Date: 12/07/23, 01/03/24 Product No. 4226, 4227',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cbc'),
#   'Status': 'Terminated',
#   'City': 'Coldwater',
#   'State': 'MS',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '84863',
#   'Recalling Firm': 'Southern Sisters Gourmet',
#   'Address 1': '5377 Highway 306',
#   'Address 2': 'N/A',
#   'Postal Code': '38618-5119',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Telephone',
#   'Distribution Pattern': 'Distributed in the states of AL, AR, FL, GA, IL, LA, MS, OK, and TX.',
#   'Recall Number': 'F-0913-2020',
#   'Product Description': 'Southern Sisters Gourmet Cheddar Garlic Biscuits, Net Wt 16 oz (453.6 g)',
#   'Product Quantity': 'Unknown',
#   'Reason for Recall': 'Undeclared allergen: Wheat  Undeclared colors: Yellow #5 and #6.',
#   'Recall Initiation Date': '20200128',
#   'Center Classification Date': '20200417',
#   'Termination Date': '20210216',
#   'Report Date': '20200401',
#   'Code Info': 'Products are not coded.',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cbd'),
#   'Status': 'Terminated',
#   'City': 'Owings Mills',
#   'State': 'MD',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '94829',
#   'Recalling Firm': 'Totally Cool, Inc.',
#   'Address 1': '38 Gwynns Mill Ct',
#   'Address 2': 'N/A',
#   'Postal Code': '21117-3512',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'E-Mail',
#   'Distribution Pattern': 'Distributed nationwide.',
#   'Recall Number': 'F-1594-2024',
#   'Product Description': 'Marco Turkish Mocha Ice Cream 16 fl oz/1 pint, UPC 860001992885. Packaged in paper containers, 8 containers per case.',
#   'Product Quantity': '15541 cases',
#   'Reason for Recall': 'Possible contamination with Listeria monocytogenes',
#   'Recall Initiation Date': '20240613',
#   'Center Classification Date': '20240801',
#   'Termination Date': '20241008',
#   'Report Date': '20240807',
#   'Code Info': 'All Best by Dates: 06/07/24 to 12/11/25 Codes between: 2312341 to 2406163',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cbe'),
#   'Status': 'Terminated',
#   'City': 'Jessup',
#   'State': 'MD',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '93540',
#   'Recalling Firm': 'TGD Cuts, LLC',
#   'Address 1': '8441 Dorsey Run Rd Unit B',
#   'Address 2': 'N/A',
#   'Postal Code': '20794-9359',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'Distributed in PA, NJ, MD, WV, SC VA, DE, NC, and NY',
#   'Recall Number': 'F-0678-2024',
#   'Product Description': 'MIX FRUIT ALOHA BOWL 3/48 OZ Packaged in clamshell container. UPC:840219170299',
#   'Product Quantity': '189 units',
#   'Reason for Recall': 'Potential Salmonella Contamination',
#   'Recall Initiation Date': '20231129',
#   'Center Classification Date': '20240102',
#   'Termination Date': '20240925',
#   'Report Date': '20231227',
#   'Code Info': 'Use By Start Date: 11/2/2023  Use By End Date: 11/23/2023',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cbf'),
#   'Status': 'Terminated',
#   'City': 'New Century',
#   'State': 'KS',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '94565',
#   'Recalling Firm': 'Danisco USA Inc.',
#   'Address 1': '4 New Century Pkwy',
#   'Address 2': 'N/A',
#   'Postal Code': '66031-1144',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'US: AZ, CA, CO, FL, IA, ID, IL, IN, KS, KY, MI, MN, MO, NE, NJ, NY, OH, OK, PA, TN, TX, UT, VA, WI; Canada, and Mexico',
#   'Recall Number': 'F-1333-2024',
#   'Product Description': 'Grindsted Sweetlife CINN. Roll BAS Stabilizer & Emulsifier System, 22.68 kg/ 50 lb bag',
#   'Product Quantity': '7257.60 kg',
#   'Reason for Recall': 'Potential Salmonella Contamination',
#   'Recall Initiation Date': '20240503',
#   'Center Classification Date': '20240606',
#   'Termination Date': '20240904',
#   'Report Date': '20240612',
#   'Code Info': 'Lot number: 1204607256; 1204607257; 1204607258; 1204607259; 1204607260; 1204607261; 1204607262; 1204607264',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cc0'),
#   'Status': 'Terminated',
#   'City': 'Kansas City',
#   'State': 'KS',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '90164',
#   'Recalling Firm': "Liberty Fruit Co Inc DBA Carol's Cuts",
#   'Address 1': '1251 Argentine Blvd',
#   'Address 2': '',
#   'Postal Code': '66105-1508',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Telephone',
#   'Distribution Pattern': 'Distributed to food service locations in Kansas, Nebraska, Iowa, and Missouri.',
#   'Recall Number': 'F-1159-2022',
#   'Product Description': 'POTATO RUSSET QUARTERED 2/10# (01)10886810715115(10)0016086772 71511 Best if used by: 03/25/22, 03/29/22, 04/05/22, 04/06/22, 04/12/22, 04/16/22, 04/20/22, 04/23/22 Ingredients: Potato, Sodium Metabisulfite',
#   'Product Quantity': '25,433 lbs (total)',
#   'Reason for Recall': 'Sodium metabisulfite not declared on product label.',
#   'Recall Initiation Date': '20220506',
#   'Center Classification Date': '20220603',
#   'Termination Date': '20221027',
#   'Report Date': '20220615',
#   'Code Info': 'Best if used by: 03/25/22, 03/29/22, 04/05/22, 04/06/22, 04/12/22, 04/16/22, 04/20/22, 04/23/22 Product #: 71511',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cc1'),
#   'Status': 'Terminated',
#   'City': 'Chicopee',
#   'State': 'MA',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '84751',
#   'Recalling Firm': "Rachael's Food Corporation",
#   'Address 1': '705 Meadow St',
#   'Address 2': 'N/A',
#   'Postal Code': '01013-4820',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'MA',
#   'Recall Number': 'F-0597-2020',
#   'Product Description': "Rachael's brand and Big Y brand Protein Snack Packs; containing one hard boiled egg, diced roasted turkey, and roasted almonds; packaged in 6x6 plastic containers, Net. wt. 4.25 oz.",
#   'Product Quantity': '87 protein packs',
#   'Reason for Recall': 'Product may be contaminated with Listeria monocytogenes.',
#   'Recall Initiation Date': '20191231',
#   'Center Classification Date': '20200204',
#   'Termination Date': '20200325',
#   'Report Date': '20200212',
#   'Code Info': 'Production Dates: Dec 27, Dec 29, Dec 30, Jan 1  Rachael s code: 81190701592 and Big Y code: 01889490543',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cc2'),
#   'Status': 'Terminated',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '92423',
#   'Recalling Firm': 'Newly Weds Foods, Inc.',
#   'Address 1': '8550 W Bryn Mawr Ave',
#   'Address 2': 'Suite 100',
#   'Postal Code': '60631-3222',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Letter',
#   'Distribution Pattern': 'ALABAMA, ARKANSAS, CALIFORNIA, COLORADO, FLORIDA, GEORGIA, ILLINOIS, INDIANA, IOWA, KANSAS, KENTUCKY, LOUISIANA, MICHIGAN, MINNESOTA, MISSISSIPPI, MISSOURI, MONTANA, NEBRASKA, NEW JERSEY, NEW YORK, NORTH CAROLINA, OHIO, OKLAHOMA, OREGON, PENNSYLVANIA, TENNESSEE, TEXAS ,WISCONSIN.  CANADA.',
#   'Recall Number': 'F-1039-2023',
#   'Product Description': 'A53643\tBREADER   X1\t50.00\tBAG',
#   'Product Quantity': '6,465,115.78 pounds Total',
#   'Reason for Recall': 'Products may contain Salmonella',
#   'Recall Initiation Date': '20230526',
#   'Center Classification Date': '20230705',
#   'Termination Date': '20240723',
#   'Report Date': '20230712',
#   'Code Info': 'SE102922A SE110722A',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cc3'),
#   'Status': 'Terminated',
#   'City': 'Baltimore',
#   'State': 'MD',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '91653',
#   'Recalling Firm': 'FRESH IDEATION FOOD GROUP, LLC dba Fresh Creative Cuisine',
#   'Address 1': '2800 Wegworth Ln',
#   'Address 2': 'N/A',
#   'Postal Code': '21230-3300',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Press Release',
#   'Distribution Pattern': 'The recalled product was distributed to the following states: MD, PA, DE, NY, DC, NJ, NC, CT, SC, VA, MA .',
#   'Recall Number': 'F-0459-2023',
#   'Product Description': 'Bistro To Go, Gourmet Cheese & Fruit Plate, Net Wt. 6 Oz. Single Serving, Keep refrigerated',
#   'Product Quantity': '18 units',
#   'Reason for Recall': 'On 02/03/2023, FRESH IDEATION FOOD GROUP, LLC dba Fresh Creative Cuisine of Baltimore, MD is  initiating a recall of  various products sold from January 24, 2023 through January 30, 2023 because the products have the potential to be contaminated with Listeria monocytogenes .',
#   'Recall Initiation Date': '20230203',
#   'Center Classification Date': '20231017',
#   'Termination Date': '20231017',
#   'Report Date': '20230322',
#   'Code Info': 'UPC Code : 813141021144',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cc4'),
#   'Status': 'Terminated',
#   'City': 'Visalia',
#   'State': 'CA',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '89115',
#   'Recalling Firm': 'Livia Global',
#   'Address 1': '7202 W Pershing Ct',
#   'Address 2': '',
#   'Postal Code': '93291-7909',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Press Release',
#   'Distribution Pattern': 'xx',
#   'Recall Number': 'F-0358-2022',
#   'Product Description': 'Livia One Organic Daily Topical Spray Probiotics;   4 oz. (120 ml)  UPC: 0 30915 10710 5     Recommended use: Topical: Spray affected area 2-5 times daily as needed.     Ingredients: Proprietary probiotic blend in an enzyme enriched substrate:  Lactobacillus-Acidophilus, L. Rhamnosus, L-Salivarius, L. Casei, L-Plantarum, Lactococcus-Lactis, Streptocuccus-Thermophilus, Bifidobacterium-Bifidum, B-Lactus, B-Infantis, B-Breve, B-Longum.  Made with water and a proprietary blend of three organic grasses    Livia Global Inc., Visalia, CA.',
#   'Product Quantity': '571 bottles',
#   'Reason for Recall': 'Probiotic products contaminated with Pseudomonas aeruginosa .',
#   'Recall Initiation Date': '20211201',
#   'Center Classification Date': '20220102',
#   'Termination Date': '20220429',
#   'Report Date': '20211222',
#   'Code Info': 'Lot #001005-1, BB 04/2023',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cc5'),
#   'Status': 'Ongoing',
#   'City': 'Charleston',
#   'State': 'SC',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '84523',
#   'Recalling Firm': 'TFI Holding dba Grey Ghost Bakery',
#   'Address 1': '1750 Signal Point Rd Ste 2a',
#   'Address 2': 'N/A',
#   'Postal Code': '29412-8056',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Letter',
#   'Distribution Pattern': 'Product was shipped to the following states: AL, AR, AZ, CA, CO, CT, DC, DE, FL GA, HI, IA, ID, IL, IN, KS, KY, LA, MA, MD, MI, MN, MO, MS, NC, NH, NJ, NM, NY, OH, OK, OR, PA, SC, TN, TX, UT, VA, WA, WI & WY.',
#   'Recall Number': 'F-0559-2020',
#   'Product Description': 'GREY GHOST BAKERY scratch-made cookies LEMON SUGAR NET WT 1.4 OZ (40 G), UPC 8 53152 00308 1 , 4 OZ (113 G) UPC 8 53152 00332 6 & 8 OZ (225 G) UPC 8 53152 00307 4 GREY GHOST BAKERY 1750 SIGNAL POINT RD, STE 2A CHARLESTON, SC 29412',
#   'Product Quantity': 'Bulk cookies: 70 lbs, 8 oz boxes: 2899 units; 4 oz canisters: 1717 units; 1.4 oz packs: 2101 units',
#   'Reason for Recall': 'The product contains undeclared sulfites.',
#   'Recall Initiation Date': '20191217',
#   'Center Classification Date': '20200124',
#   'Termination Date': nan,
#   'Report Date': '20200115',
#   'Code Info': '1612019, 1622019, 1632019, 1752019, 1772019, 1782019, 1802019, 1822019, 1892019, 1912019, 1962019, 1972019, 1982019, 2042019, 2052019, 2062019, 2082019, 2112019, 2132019, 2142019, 2192019, 2212019, 2252019, 2272019, 2282019, 2312019, 2332019, 2412019, 2542019, 2552019, 2572019, 2632019, 2682019, 2692019, 2712019, 2742019, 2752019, 2762019, 2772019, 2782019, 2822019, 2882019, 2912019, 2922019, 2952019, 2962019, 2972019, 3042019, 3062019, 3082019, 3102019, 3122019, 3172019, 3192019, 3212019, 3252019, 3282019, 3302019, 3362019, 3372019, 3382019, 3452019.',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cc6'),
#   'Status': 'Terminated',
#   'City': 'Mesa',
#   'State': 'AZ',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '89587',
#   'Recalling Firm': 'Lehi Valley Trading Co, Inc',
#   'Address 1': '4955 E McKellips Rd',
#   'Address 2': 'N/A',
#   'Postal Code': '85215-2531',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'Nationwide.',
#   'Recall Number': 'F-0910-2022',
#   'Product Description': "Woody's Smokehouse brand Yogurt Raisins, 12.3 oz. (348g), clear plastic bag with front and back labels, UPC 0 95248 65531 0. Packed especially for Woody's Smokehouse Inc., Centerville, TX 75833, 903-536-9663, Woody's-Smokehouse.com  Texas Best Smokehouse brand Yogurt Raisins, 8 oz. (226g), clear plastic bag with front and back labels, UPC 0 95248 32055 3. Packed especially for: Texas Best Smokehouse, 3302 S Eastman Rd., Longview TX 75602.  Snack-Worthy brand Yogurt Raisins, 10 oz. (283g), clear plastic tub with front and back labels, UPC 8 79114 00668 3. Distributed by Lehi Valley Trading Company, Mesa, AZ 85215 snackworthy.com.",
#   'Product Quantity': '36 12.3 oz. bags; 24 8.0 oz. bags; 312 10 oz. tubs',
#   'Reason for Recall': 'Bags and tubs of yogurt covered raisins contained undeclared  peanuts.',
#   'Recall Initiation Date': '20220211',
#   'Center Classification Date': '20220328',
#   'Termination Date': '20220519',
#   'Report Date': '20220406',
#   'Code Info': "Woody's Smokehouse - Lot Code: 222447, Best by: August 23, 2022 Texas Best - Lot Code: 222456, August 23, 2022 Snack Worthy - Lot Code: 222268, 09/12/22",
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cc7'),
#   'Status': 'Terminated',
#   'City': 'Caledonia',
#   'State': 'MI',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '92065',
#   'Recalling Firm': 'Caledonia Facility of Revolution Farms LLC',
#   'Address 1': '2901 76th St Se',
#   'Address 2': 'N/A',
#   'Postal Code': '49316-8399',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'MI, OH, WI',
#   'Recall Number': 'F-0829-2023',
#   'Product Description': 'Revolution Farms Zesty Southwest 6oz salad kit in plastic container UPC 856791008240',
#   'Product Quantity': '66',
#   'Reason for Recall': 'Listeria monocytogenes',
#   'Recall Initiation Date': '20230405',
#   'Center Classification Date': '20230506',
#   'Termination Date': '20230509',
#   'Report Date': '20230517',
#   'Code Info': 'Sell By 3/23/23',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cc8'),
#   'Status': 'Terminated',
#   'City': 'Garden City',
#   'State': 'MI',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '87576',
#   'Recalling Firm': 'KAREEM MART INC',
#   'Address 1': '32816 Manor Park',
#   'Address 2': '',
#   'Postal Code': '48135-1545',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Telephone',
#   'Distribution Pattern': 'The recalled  Halva  were distributed through Mediterranean food stores and wholesalers in Michigan, Illinois, Missouri, New York, Ohio, North Carolina and  Pennsylvania.  Between March 2020 to Feb 2021.',
#   'Recall Number': 'F-0377-2021',
#   'Product Description': 'Kareem Chef Halva 1lb and 2lb sizes in plastic tub',
#   'Product Quantity': '1320 units',
#   'Reason for Recall': 'Salmonella',
#   'Recall Initiation Date': '20210308',
#   'Center Classification Date': '20210330',
#   'Termination Date': '20210901',
#   'Report Date': '20210407',
#   'Code Info': 'Best Before 07-01-2022',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cc9'),
#   'Status': 'Terminated',
#   'City': 'New York',
#   'State': 'NY',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '88958',
#   'Recalling Firm': 'HELLOFRESH US',
#   'Address 1': '40 W 25th St',
#   'Address 2': 'N/A',
#   'Postal Code': '10010-2707',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Other',
#   'Distribution Pattern': 'Nationwide.',
#   'Recall Number': 'F-0202-2022',
#   'Product Description': 'EveryPlate Meal Kit Product Codes 81-82-84-90-92-95-98-99 from Production Week 32 (production week start date: 08/04/2021)',
#   'Product Quantity': 'N/A',
#   'Reason for Recall': 'Products contain onions purchased from ProSource and associated with a Salmonella Oranienburg outbreak.',
#   'Recall Initiation Date': '20211022',
#   'Center Classification Date': '20211118',
#   'Termination Date': '20220901',
#   'Report Date': '20211124',
#   'Code Info': 'Production Week: 08/04/2021 EveryPlate Product Code: 81-82-84-90-92-95-98-99 (Number sequence may vary)',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cca'),
#   'Status': 'Terminated',
#   'City': 'Cleveland',
#   'State': 'OH',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '93817',
#   'Recalling Firm': 'Greco Sidari',
#   'Address 1': '3820 Lakeside Ave E',
#   'Address 2': '',
#   'Postal Code': '44114-3848',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'OH, NY & PA',
#   'Recall Number': 'F-0848-2024',
#   'Product Description': 'GRANDE     1.5OZ FRESH BOCCONCINI MOZZ 1/3#         SUPC/ITEM # 19132P',
#   'Product Quantity': '1375 cases total',
#   'Reason for Recall': 'The food was not held at an appropriate temperature.  The holding temperature could affect spoilage and potentially support pathogen growth.',
#   'Recall Initiation Date': '20240111',
#   'Center Classification Date': '20240205',
#   'Termination Date': '20240905',
#   'Report Date': '20240214',
#   'Code Info': 'All Lot Codes Distributed between November 26, 2023 and January 5, 2024',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69ccb'),
#   'Status': 'Terminated',
#   'City': 'Piscataway',
#   'State': 'NJ',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '87961',
#   'Recalling Firm': 'Clio LLC',
#   'Address 1': '141 Ethel Rd W',
#   'Address 2': '',
#   'Postal Code': '08854-5928',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'Distributed nationwide',
#   'Recall Number': 'F-0634-2021',
#   'Product Description': 'Clio No Added Sugar Yogurt Bar Mixed Berry / Peach  50g x 16 (12pc tray). UPC Code: 854021008220',
#   'Product Quantity': '1880 units',
#   'Reason for Recall': 'Possible metal fragments in Yogurt Bars',
#   'Recall Initiation Date': '20210515',
#   'Center Classification Date': '20210528',
#   'Termination Date': '20220414',
#   'Report Date': '20210609',
#   'Code Info': '110PB1132021 7/4/2021  110PB113PP2021 7/4/2021  110PB114PP2021 7/4/2021  111PB1142021 7/4/2021  117PB1162021 7/4/2021  117PB116PP2021 7/4/2021',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69ccc'),
#   'Status': 'Terminated',
#   'City': 'Windermere',
#   'State': 'FL',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '85918',
#   'Recalling Firm': 'Fresh Express Incorporated',
#   'Address 1': '4757 The Grove Dr',
#   'Address 2': 'N/A',
#   'Postal Code': '34786-8426',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'E-Mail',
#   'Distribution Pattern': 'Domestic: Midwestern states of AR, CT, DC, DE, IA, IL, IN, KS, KY, MA, MD, ME, MI, MN, MO, MT, NC, ND, NE, NH, NJ, NY, OH, OK, PA, RI, SD, TN, VA, VT, WI, WV  Foreign: Canada',
#   'Recall Number': 'F-1052-2020',
#   'Product Description': 'Little Salad Bar Garden, 12 oz, UPC 4099100082975, Iceberg lettuce, carrots & red cabbage',
#   'Product Quantity': 'unknown',
#   'Reason for Recall': 'Ready to Eat salad products containing iceberg lettuce, red cabbage and/or carrot ingredients are recalled due to a possible health risk from Cyclospora.',
#   'Recall Initiation Date': '20200619',
#   'Center Classification Date': '20200804',
#   'Termination Date': '20201216',
#   'Report Date': '20200722',
#   'Code Info': 'Product Code  Z122, Z125, Z126, Z128, Z129, Z130, Z132, Z133, Z134, Z135, Z136, Z139, Z140, Z141, Z142, Z143, Z144, Z145, Z148, Z149, Z150, Z153, Z154, Z155, Z156, Z157, Z158, Z160, Z161, Z162, Z163, Z164, Z165, Z167, Z168, Z169. USED BY  or Before 7/3/2020',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69ccd'),
#   'Status': 'Ongoing',
#   'City': 'Jamaica',
#   'State': 'NY',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '95061',
#   'Recalling Firm': 'American Spice LLC',
#   'Address 1': '10108 97th St',
#   'Address 2': 'Apt 2R',
#   'Postal Code': '11416-2549',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'New York',
#   'Recall Number': 'F-1745-2024',
#   'Product Description': 'Spice Class brand Ground Cinnamon packed in 7oz and 11oz PET jars',
#   'Product Quantity': '1,224 units',
#   'Reason for Recall': 'Product contains elevated levels of lead (2,040ppb).',
#   'Recall Initiation Date': '20240528',
#   'Center Classification Date': '20240823',
#   'Termination Date': nan,
#   'Report Date': '20240904',
#   'Code Info': 'Expiration date: 12/2026',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cce'),
#   'Status': 'Terminated',
#   'City': 'Oxnard',
#   'State': 'CA',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '93290',
#   'Recalling Firm': 'Gills Onions, LLC',
#   'Address 1': '1051 Pacific Ave',
#   'Address 2': '',
#   'Postal Code': '93030-7254',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'Distributors in Canada   AB, BC, NB, NS, ON; and the United States   AZ, CA, CO, CT, FL, GA, IA, ID, IL, IN, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NM, NV, OH, OK, OR, PA, SC, TN, TX, UT, VA, WA and WI.',
#   'Recall Number': 'F-0346-2024',
#   'Product Description': 'Cross Valley Farms 4/5 LB CTN FRESH 1/8" SLIVERED YELLOW ONIONS W/ZIPPER',
#   'Product Quantity': '6,400 lb',
#   'Reason for Recall': 'Potential contamination with Salmonella Thompson',
#   'Recall Initiation Date': '20231023',
#   'Center Classification Date': '20231108',
#   'Termination Date': '20240920',
#   'Report Date': '20231115',
#   'Code Info': 'Product 6514182006CV; Finished product lots: 223YAC2A1P205 223YAC2A2R202 223YAM4A1P220 223YAM4B1P213 223YAS3A1P207 223YAS3A1P209 223YAS3A1P215 223YAS3A1P219',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69ccf'),
#   'Status': 'Terminated',
#   'City': 'Miami',
#   'State': 'FL',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '92215',
#   'Recalling Firm': 'Borris Brothers',
#   'Address 1': '12254 Sw 131st Ave Unit 2',
#   'Address 2': 'N/A',
#   'Postal Code': '33186-6482',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'U.S. distribution within state of Florida. No foreign distribution.',
#   'Recall Number': 'F-0881-2023',
#   'Product Description': 'Smoked Mahi Dip, Net Wt. 8oz and 48oz',
#   'Product Quantity': '95 containers of 8oz and 4 containers of 48oz',
#   'Reason for Recall': 'Undeclared Yellow #5',
#   'Recall Initiation Date': '20230413',
#   'Center Classification Date': '20230511',
#   'Termination Date': '20230622',
#   'Report Date': '20230517',
#   'Code Info': 'Batch #3-401',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cd0'),
#   'Status': 'Terminated',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '87840',
#   'Recalling Firm': 'Newly Weds Foods Inc',
#   'Address 1': '4140 W Fullerton Ave',
#   'Address 2': 'N/A',
#   'Postal Code': '60639-2106',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'E-Mail',
#   'Distribution Pattern': 'Manufacturers and distributors located in ALABAMA, ARKANSAS, CALIFORNIA, CONNECTICUT, FLORIDA, GEORGIA, ILLINOIS, IOWA, KANSAS, LOUISIANA, MISSISSIPPI, MISSOURI, NEW YORK, TENNESSEE, TEXAS, VIRGINIA, and MEXICO.',
#   'Recall Number': 'F-0523-2021',
#   'Product Description': 'Newly Weds B70731 bread crumbs X1, 25lbs bag',
#   'Product Quantity': '489 bags',
#   'Reason for Recall': 'Foreign material',
#   'Recall Initiation Date': '20210427',
#   'Center Classification Date': '20210518',
#   'Termination Date': '20220209',
#   'Report Date': '20210526',
#   'Code Info': 'Lot numbers:  MS040421J',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cd1'),
#   'Status': 'Terminated',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '87840',
#   'Recalling Firm': 'Newly Weds Foods Inc',
#   'Address 1': '4140 W Fullerton Ave',
#   'Address 2': 'N/A',
#   'Postal Code': '60639-2106',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'E-Mail',
#   'Distribution Pattern': 'Manufacturers and distributors located in ALABAMA, ARKANSAS, CALIFORNIA, CONNECTICUT, FLORIDA, GEORGIA, ILLINOIS, IOWA, KANSAS, LOUISIANA, MISSISSIPPI, MISSOURI, NEW YORK, TENNESSEE, TEXAS, VIRGINIA, and MEXICO.',
#   'Recall Number': 'F-0521-2021',
#   'Product Description': 'Newly Weds B70709 breader crumbs X3, 40lbs bag',
#   'Product Quantity': '142 bags',
#   'Reason for Recall': 'Foreign material',
#   'Recall Initiation Date': '20210427',
#   'Center Classification Date': '20210518',
#   'Termination Date': '20220209',
#   'Report Date': '20210526',
#   'Code Info': 'Lot numbers:  MS040321J',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cd2'),
#   'Status': 'Terminated',
#   'City': 'Albuquerque',
#   'State': 'NM',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '92936',
#   'Recalling Firm': 'Vitality Works, Inc',
#   'Address 1': '8500 Bluewater Rd NW',
#   'Address 2': 'N/A',
#   'Postal Code': '87121-1958',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': '55 Retail customers, representing 284 individual stores.  All customers are located within the United States. There is no foreign distribution. There is no distribution to US Government agencies or departments. Distribution is by small parcel shipper (UPS, FedEx).  Distribution Chain Notification Date: August 24, 2023',
#   'Recall Number': 'F-1563-2023',
#   'Product Description': '100 vegetarian  Fenugreek Capsules 90 count, 600mg, packaged in 150cc Amber Glass Packer  with White Polypropylene Cap.',
#   'Product Quantity': '1,025 bottles (total)',
#   'Reason for Recall': 'Foreign material: pieces of a pen (writing utensil).',
#   'Recall Initiation Date': '20230822',
#   'Center Classification Date': '20230922',
#   'Termination Date': '20231113',
#   'Report Date': '20231004',
#   'Code Info': 'Lot 2023-06871  (Lot numbers are generated by our ERP system and use the 4-digit year followed by a 5-digit sequential number.) Expires: 07/2028 Bottom Code: FENUGRK PCAP 202306871 EXP 07/28',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cd3'),
#   'Status': 'Ongoing',
#   'City': 'El Paso',
#   'State': 'TX',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '92844',
#   'Recalling Firm': 'Mount Franklin Foods LLC DBA Azar Nut Co.',
#   'Address 1': '1800 Northwestern Dr',
#   'Address 2': '',
#   'Postal Code': '79912-1122',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'E-Mail',
#   'Distribution Pattern': 'Nationwide',
#   'Recall Number': 'F-1517-2023',
#   'Product Description': 'Power Snacks Honey Roasted Sunflower Kernels, Net Wt 1 oz; UPC 076500722025',
#   'Product Quantity': '88,084 total',
#   'Reason for Recall': 'Potential to contain undeclared soy and/or wheat allergen due to mislabeling.',
#   'Recall Initiation Date': '20230816',
#   'Center Classification Date': '20230915',
#   'Termination Date': nan,
#   'Report Date': '20230927',
#   'Code Info': 'Best Used By: 3/21/2024, 3/23/2024, 3/24/2024, 3/26/2024, 3/27/2024, 4/4/2024, 4/5/2024, 4/6/2024, 4/7/2024, 4/11/2024, 4/12/2024, 4/13/2024, 6/12/2024',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cd4'),
#   'Status': 'Terminated',
#   'City': 'Coral Gables',
#   'State': 'FL',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '94530',
#   'Recalling Firm': 'CN Frozen Foods, INC',
#   'Address 1': '2330 Ponce De Leon Blvd',
#   'Address 2': 'N/A',
#   'Postal Code': '33134-5417',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'E-Mail',
#   'Distribution Pattern': 'Product was only sold in Texas.',
#   'Recall Number': 'F-1243-2024',
#   'Product Description': 'Sysco Classic Riced Cauliflower packed in a 4lb plastic bag (6 units of 4 lb. per carton box).',
#   'Product Quantity': '3,240 cases',
#   'Reason for Recall': 'Riced Cauliflower tested positive for Listeria monocytogenes.',
#   'Recall Initiation Date': '20240427',
#   'Center Classification Date': '20240515',
#   'Termination Date': '20240624',
#   'Report Date': '20240522',
#   'Code Info': 'Manufacture #: 30.05.2023  Best Buy Date: 05/2025 Reorder #: 5087729',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cd5'),
#   'Status': 'Ongoing',
#   'City': 'Buffalo',
#   'State': 'NY',
#   'Country': 'United States',
#   'Classification': 'Class III',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '92770',
#   'Recalling Firm': 'The Sausage Maker, Inc.',
#   'Address 1': '1500 Clinton St Bldg 7',
#   'Address 2': '',
#   'Postal Code': '14206-3015',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'online orders nationwide',
#   'Recall Number': 'F-0405-2024',
#   'Product Description': 'The Sausage Maker Instacure #1',
#   'Product Quantity': '995 lbs.',
#   'Reason for Recall': 'Contains Sodium Nitrite recalled for potential metal contamination',
#   'Recall Initiation Date': '20230725',
#   'Center Classification Date': '20231109',
#   'Termination Date': nan,
#   'Report Date': '20231115',
#   'Code Info': 'Lot 30508DA010  Manf. 5/8/23 Cat No. 11-1013',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cd6'),
#   'Status': 'Terminated',
#   'City': 'Inglewood',
#   'State': 'CA',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '88824',
#   'Recalling Firm': 'Chocolate and the Chip',
#   'Address 1': '705 Vesta St',
#   'Address 2': 'N/A',
#   'Postal Code': '90302-3316',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Press Release',
#   'Distribution Pattern': 'Nationwide distribution',
#   'Recall Number': 'F-0043-2022',
#   'Product Description': 'Chocolate & the Chip  Boozy Banana Walnut:  Cookies: 4 oz / 114 grams per pack. Cookies are packaged in uniform pairs in a food grade clear resealable bag and label  Corrected Ingredients: Not provided    Labels found during the inspection had undeclared wheat, milk, soy sulfites. Firm had listed ingredients on packaging but what was missing were the sub ingredients and allergen containment.',
#   'Product Quantity': '3000 units (total)',
#   'Reason for Recall': 'Inspection by the California Department of Public Health found undeclared allergens in numerous bakery products.',
#   'Recall Initiation Date': '20211005',
#   'Center Classification Date': '20211020',
#   'Termination Date': '20211130',
#   'Report Date': '20211027',
#   'Code Info': 'Product manufactured from July 1, 2021 to 9-30-21.',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cd7'),
#   'Status': 'Terminated',
#   'City': 'Marietta',
#   'State': 'GA',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '91329',
#   'Recalling Firm': 'Something South African LLC',
#   'Address 1': '825 Franklin Ct Se Ste B',
#   'Address 2': 'N/A',
#   'Postal Code': '30067-8944',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'E-Mail',
#   'Distribution Pattern': 'nationwide',
#   'Recall Number': 'F-0263-2023',
#   'Product Description': 'Pepper Collection 8 Tube Gift Set - a colorful assortment of dried peppers.  This product contains peppers in 8 different glass tube and packaged in a printed paperboard sleeve and are visible through a window in the sleeve. Net wt. is 4.87oz/138g. The UPC is 6 009686 793712.  Packed in South Africa. US Importer: Something South African, LLC Seattle WA 98199, Email: info@somethingsouthafrican.net.',
#   'Product Quantity': '4200 units',
#   'Reason for Recall': 'Due to presence of mold (Aspergillus brasiliensis) and Ochratoxin A.',
#   'Recall Initiation Date': '20221212',
#   'Center Classification Date': '20230113',
#   'Termination Date': '20230424',
#   'Report Date': '20230125',
#   'Code Info': 'BBE: JUN/2024. Batch: 494951 -T',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cd8'),
#   'Status': 'Ongoing',
#   'City': 'Danville',
#   'State': 'IL',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '93631',
#   'Recalling Firm': 'The Quaker Oats Co.',
#   'Address 1': '1703 E Voorhees St',
#   'Address 2': '',
#   'Postal Code': '61834-6256',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'This product was distributed and sold nationally in all states, Puerto Rico, Guam, and Saipan, as well as outside of the United States.',
#   'Recall Number': 'F-0950-2024',
#   'Product Description': 'Quaker Chewy Bars Less Sugar Peanut Butter Chocolate Chip 8ct 6.7 oz. Bars are individually wrapped in plastic and then packaged in paperboard boxes.',
#   'Product Quantity': '22,512,942 total cases for all products',
#   'Reason for Recall': 'potential Salmonella',
#   'Recall Initiation Date': '20231215',
#   'Center Classification Date': '20240227',
#   'Termination Date': nan,
#   'Report Date': '20240306',
#   'Code Info': 'Best Before of Aug-02-24 and any earlier date',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cd9'),
#   'Status': 'Terminated',
#   'City': 'Nof Ha-Galil',
#   'State': '',
#   'Country': 'Israel',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '90105',
#   'Recalling Firm': 'ELITE CONFECTIONERY LTD',
#   'Address 1': 'Nazareth-Ilit',
#   'Address 2': "5, Gilbo'A",
#   'Postal Code': 'N/A',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'Distributed in the US nationwide',
#   'Recall Number': 'F-1203-2022',
#   'Product Description': 'ELITE PESEK ZMAN WAFER ROLL UPC: 815871011495 NET WT. 1.4 oz (40g)',
#   'Product Quantity': 'unknown',
#   'Reason for Recall': 'Potential contamination with Salmonella',
#   'Recall Initiation Date': '20220428',
#   'Center Classification Date': '20220604',
#   'Termination Date': '20221103',
#   'Report Date': '20220615',
#   'Code Info': 'All lots',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69cda'),
#   'Status': 'Terminated',
#   'City': 'Fort Myers',
#   'State': 'FL',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '94308',
#   'Recalling Firm': 'Belgian Yummies',
#   'Address 1': '7970 Summerlin Lakes Dr Ste 101',
#   'Address 2': 'N/A',
#   'Postal Code': '33907-1855',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'The products were only distributed in the state of Florida.',
#   'Recall Number': 'F-1230-2024',
#   'Product Description': 'Vanilla Ice Cream Cookie Sandwich. Sandwiches packaged in a gold or clear bags. 50 sandwiches per case and weighting 4oz each sandwich.',
#   'Product Quantity': '1208.',
#   'Reason for Recall': 'Undeclared Allergen: milk, eggs, wheat, peanuts, and tree nuts.',
#   'Recall Initiation Date': '20240320',
#   'Center Classification Date': '20240509',
#   'Termination Date': '20240716',
#   'Report Date': '20240515',
#   'Code Info': 'No lot numbers provided; Expiration date is 6 months from production date.',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69cdb'),
#   'Status': 'Terminated',
#   'City': 'Friesland',
#   'State': 'WI',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
# ...
#   'Product Description': 'JUST Egg Inspired by Japan Portobello, Mushrooms, Sweet Potatos, Furikake, Soy 4 Sous Vide Plant Egg Bites NET WT8.4OZ (238g). UPC: 0504402523, Expiration dates 3/5/2022, 3/31/2022, and 4/9/2022.16 cartons per corrugated case, Carton GTIN 7 05044 02523 0, Case Bar Code 10 750 440 25237',
#   'Product Quantity': '320 units',
#   'Reason for Recall': 'Undeclared egg and milk',
#   'Recall Initiation Date': '20210618',
#   'Center Classification Date': '20210625',
#   'Termination Date': '20220330',
#   'Report Date': '20210707',
#   'Code Info': '82790 and 83231',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69e9c'),
#   'Status': 'Terminated',
#   'City': 'Orrville',
#   'State': 'OH',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '90255',
#   'Recalling Firm': 'The JM Smucker Company LLC',
#   'Address 1': '1 Strawberry Ln',
#   'Address 2': 'N/A',
#   'Postal Code': '44667-1241',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'AK, AL, AR, AZ, CA, CO, CT, DE, FL, GA, HI, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, TN, TX, UT, VA, VT, WA, WI, WV, WY',
#   'Recall Number': 'F-1120-2022',
#   'Product Description': 'JIF NO ADDED SUGAR PEANUT BUTTER packaged in 15.5oz and 46.5oz',
#   'Product Quantity': '115,106 cases total',
#   'Reason for Recall': 'Products are potentially contaminated with Salmonella.',
#   'Recall Initiation Date': '20220520',
#   'Center Classification Date': '20220601',
#   'Termination Date': '20230317',
#   'Report Date': '20220608',
#   'Code Info': 'Lot codes: 1274425   2140425 UPC: 5150024540, 5150041418 Best By Date: 10/01/22 - 05/20/23',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69e9d'),
#   'Status': 'Ongoing',
#   'City': 'Green Bay',
#   'State': 'WI',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '94828',
#   'Recalling Firm': 'Snapchill, LLC',
#   'Address 1': '1471 Partnership Rd',
#   'Address 2': '',
#   'Postal Code': '54304-5685',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'E-Mail',
#   'Distribution Pattern': 'Nationwide.  Outside the US:  Canada',
#   'Recall Number': 'F-1501-2024',
#   'Product Description': 'Black Coffee + Maple Syrup Canned Beverage packaged under the following brands and sizes:   1.  Mud LLC Maple Mud, 12 oz. UPC  8 54555-00705 8.',
#   'Product Quantity': '549,146 cans total',
#   'Reason for Recall': 'Potential under-processing.',
#   'Recall Initiation Date': '20240617',
#   'Center Classification Date': '20240723',
#   'Termination Date': nan,
#   'Report Date': '20240724',
#   'Code Info': 'Cans with Expiration dates between June 16, 2024 and April 16, 2025.',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69e9e'),
#   'Status': 'Terminated',
#   'City': 'Gainesville',
#   'State': 'GA',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '84543',
#   'Recalling Firm': 'Almark Foods, LLC',
#   'Address 1': '2118 Centennial Dr',
#   'Address 2': 'N/A',
#   'Postal Code': '30504-5757',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'Product was shipped to the following states: AL, AR, AZ, CA, CO, CT, DC, FL, GA, IA, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, NC, ND, NH, NJ, NV, NY, OH, OK, OR, PA, SC, TN, TX, UT, VA, WA, WI & WY.',
#   'Recall Number': 'F-0611-2020',
#   'Product Description': "Eggland's Best Hard Cooked Eggs",
#   'Product Quantity': '628,531 retail packages of various sizes (total)',
#   'Reason for Recall': 'The firm was notified by FDA & CDC of a potential Listeria monocytogenes genetic match between environmental samples from our facility and case patient samples associated with an illness outbreak.',
#   'Recall Initiation Date': '20191219',
#   'Center Classification Date': '20200204',
#   'Termination Date': '20210917',
#   'Report Date': '20200212',
#   'Code Info': 'All lot codes containing "G" with a USED BY DATE on or before 11/2020',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69e9f'),
#   'Status': 'Terminated',
#   'City': 'Baltimore',
#   'State': 'MD',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '91653',
#   'Recalling Firm': 'FRESH IDEATION FOOD GROUP, LLC dba Fresh Creative Cuisine',
#   'Address 1': '2800 Wegworth Ln',
#   'Address 2': 'N/A',
#   'Postal Code': '21230-3300',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Press Release',
#   'Distribution Pattern': 'The recalled product was distributed to the following states: MD, PA, DE, NY, DC, NJ, NC, CT, SC, VA, MA .',
#   'Recall Number': 'F-0285-2024',
#   'Product Description': 'Fresh Creative Cuisine Black Label, Vanilla Low Fat Yogurt, Mixed Berries & Granola, Net Wt. 9 Oz. Single Serving, Keep refrigerated',
#   'Product Quantity': '417',
#   'Reason for Recall': 'On 02/03/2023, FRESH IDEATION FOOD GROUP, LLC dba Fresh Creative Cuisine of Baltimore, MD is  initiating a recall of  various products sold from January 24, 2023 through January 30, 2023 because the products have the potential to be contaminated with Listeria monocytogenes .',
#   'Recall Initiation Date': '20230203',
#   'Center Classification Date': '20231017',
#   'Termination Date': '20231017',
#   'Report Date': '20230322',
#   'Code Info': 'UPC Code : 813141026019',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69ea0'),
#   'Status': 'Terminated',
#   'City': 'Fresno',
#   'State': 'CA',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '90921',
#   'Recalling Firm': 'Lyons Magnus LLC',
#   'Address 1': '3158 E Hamilton Ave',
#   'Address 2': 'N/A',
#   'Postal Code': '93702-4163',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'AK, AL, AR, AZ, CA, CO, CT, DE, FL, GA, IA, ID, IL IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV',
#   'Recall Number': 'F-0053-2023',
#   'Product Description': 'Lyons Ready Care Thickened Orange Nectar packaged in combi-bloc multi wall paper cartons 46 fl oz cartons - 6 cartons to a case',
#   'Product Quantity': '1272 cases',
#   'Reason for Recall': 'Indication of product spoilage',
#   'Recall Initiation Date': '20220923',
#   'Center Classification Date': '20221020',
#   'Termination Date': '20221118',
#   'Report Date': '20221026',
#   'Code Info': 'Batch/Lot No. 1422, 2422, 3422, 4422 Product No. 5256, 1711, 1773, 3301, 1771, 5258, 3302, 1787, 1774, 3304, 3305, 1785 Best By: 03/27/23, 03/28/23, 03/29/23, 03/30/23',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69ea1'),
#   'Status': 'Terminated',
#   'City': 'Wellman',
#   'State': 'IA',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '88745',
#   'Recalling Firm': "Farmers' All Natural Creamery LLC",
#   'Address 1': '1010 540th St Sw',
#   'Address 2': 'N/A',
#   'Postal Code': '52356-9583',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'Distributed to retail food store distributors in CA, CO, IA, IL, MN, TX, and WI',
#   'Recall Number': 'F-0021-2022',
#   'Product Description': 'Kalona Supernatural Organic Half & Half, Manufactured in Iowa for Kalona Organics, LLC. Kalona IA in 16 FL OZ (UPC 8-81245-12516-7, 8 bottles per case) and 32 FL OZ (UPC 8-81245-12532-7, 6 bottles per case)',
#   'Product Quantity': '114 cases of 16 OZ, 93 cases of 32 OZ',
#   'Reason for Recall': 'Milk products and shipped without being properly pasteurized.',
#   'Recall Initiation Date': '20210917',
#   'Center Classification Date': '20211015',
#   'Termination Date': '20211101',
#   'Report Date': '20211027',
#   'Code Info': '10/4/21',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69ea2'),
#   'Status': 'Terminated',
#   'City': 'Grand Rapids',
#   'State': 'MI',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '92119',
#   'Recalling Firm': 'Meijer Inc',
#   'Address 1': '2929 Walker Ave Nw',
#   'Address 2': 'N/A',
#   'Postal Code': '49544-6402',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'E-Mail',
#   'Distribution Pattern': 'Meijer stores in Michigan, Indiana, Illinois, Ohio, Kentucky, and Wisconsin',
#   'Recall Number': 'F-0840-2023',
#   'Product Description': 'Fresh From Meijer Cranberry Spinach Shareable Salad 12 Oz UPC - 708820304321',
#   'Product Quantity': '520',
#   'Reason for Recall': 'Listeria monocytogenes',
#   'Recall Initiation Date': '20230405',
#   'Center Classification Date': '20230509',
#   'Termination Date': '20230512',
#   'Report Date': '20230517',
#   'Code Info': 'Sell by 3/26/2023',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69ea3'),
#   'Status': 'Terminated',
#   'City': 'New Century',
#   'State': 'KS',
#   'Country': 'United States',
#   'Classification': 'Class I',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '94565',
#   'Recalling Firm': 'Danisco USA Inc.',
#   'Address 1': '4 New Century Pkwy',
#   'Address 2': 'N/A',
#   'Postal Code': '66031-1144',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'US: AZ, CA, CO, FL, IA, ID, IL, IN, KS, KY, MI, MN, MO, NE, NJ, NY, OH, OK, PA, TN, TX, UT, VA, WI; Canada, and Mexico',
#   'Recall Number': 'F-1316-2024',
#   'Product Description': 'Grindsted Creamer 2103 Stabilizer and Emulsifier System, 22. 68 kg / 50 lb bag',
#   'Product Quantity': '36265.32 kg',
#   'Reason for Recall': 'Potential Salmonella Contamination',
#   'Recall Initiation Date': '20240503',
#   'Center Classification Date': '20240606',
#   'Termination Date': '20240904',
#   'Report Date': '20240612',
#   'Code Info': 'Lot numbers: 1204582467; 1204582468; 1204582469; 1204582470; 1204583314; 1204583315; 1204583316; 1204583317; 1204583318; 1204583319; 1204583320; 1204583321; 1204583322; 1204583323; 1204583324; 1204583325; 1204583326; 1204583327; 1204583328; 1204583329; 1204583330; 1204583331; 1204583332; 1204583333; 1204583335; 1204583336; 1204583337; 1204583338; 1204583339; 1204583340; 1204583341; 1204583342; 1204583343; 1204583344; 1204583345; 1204583346; 1204583347; 1204583348; 1204583349; 1204583350; 1204583351; 1204583352; 1204583353; 1204583346',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69ea4'),
#   'Status': 'Terminated',
#   'City': 'Lovell',
#   'State': 'WY',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '90158',
#   'Recalling Firm': 'Queen Bee Gardens, LLC',
#   'Address 1': '262 E Main St',
#   'Address 2': 'N/A',
#   'Postal Code': '82431-2102',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Press Release',
#   'Distribution Pattern': 'Ten retail locations owned by Queen Bee in CO, NM, WY and nationwide via internet sales.',
#   'Recall Number': 'F-1452-2022',
#   'Product Description': 'All Milk Classic Truffle. Net Wt. 1.4 oz. PLU Code: 788394 11275 1.    Ingredients: Milk chocolate, honey, butter (pasteurized cream & salt), cream, non-fat dry milk, whey, agar, align & lecithin.     Note: Typo on website should be algin.',
#   'Product Quantity': '3352 pieces',
#   'Reason for Recall': 'Products may potentially contain one or more of the following undeclared tree nuts: Pecans, Almonds, Coconut, Macadamia Nuts, & Walnuts.',
#   'Recall Initiation Date': '20220428',
#   'Center Classification Date': '20220719',
#   'Termination Date': '20230117',
#   'Report Date': '20220727',
#   'Code Info': 'None',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69ea5'),
#   'Status': 'Terminated',
#   'City': 'Indianapolis',
#   'State': 'IN',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '91351',
#   'Recalling Firm': 'Klosterman Baking Company',
#   'Address 1': '5867 Churchman Ave',
#   'Address 2': 'N/A',
#   'Postal Code': '46203-6012',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Letter',
#   'Distribution Pattern': 'IN, OH, TN',
#   'Recall Number': 'F-0278-2023',
#   'Product Description': 'Breads: Multigrain product\t3481\tClear Bag\t\tBuns\t12\t62 g Multigrain product\t8017\tClear Bag\t\tLoaf\t1\t28 oz.',
#   'Product Quantity': '109,343 (total)',
#   'Reason for Recall': 'Products held under insanitary conditions',
#   'Recall Initiation Date': '20221218',
#   'Center Classification Date': '20230117',
#   'Termination Date': '20230124',
#   'Report Date': '20230125',
#   'Code Info': 'All product delivered between December 12 and December 16. This would include bread items with an expiration date of 12/25/22 and earlier, and any bun items with an expiration date of 12/21/22 and earlier',
#   'More Code Info': nan},
#  {'_id': ObjectId('67105b498e02bfea25a69ea6'),
#   'Status': 'Terminated',
#   'City': 'Cleveland',
#   'State': 'OH',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '93817',
#   'Recalling Firm': 'Greco Sidari',
#   'Address 1': '3820 Lakeside Ave E',
#   'Address 2': '',
#   'Postal Code': '44114-3848',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'OH, NY & PA',
#   'Recall Number': 'F-0834-2024',
#   'Product Description': 'GRANDE  SOPRAFFINA RICOTTA 1/30#  SUPC/ITEM # 19536',
#   'Product Quantity': '1375 cases total',
#   'Reason for Recall': 'The food was not held at an appropriate temperature.  The holding temperature could affect spoilage and potentially support pathogen growth.',
#   'Recall Initiation Date': '20240111',
#   'Center Classification Date': '20240205',
#   'Termination Date': '20240905',
#   'Report Date': '20240214',
#   'Code Info': 'All Lot Codes Distributed between November 26, 2023 and January 5, 2024',
#   'More Code Info': ''},
#  {'_id': ObjectId('67105b498e02bfea25a69ea7'),
#   'Status': 'Terminated',
#   'City': 'Lodi',
#   'State': 'CA',
#   'Country': 'United States',
#   'Classification': 'Class II',
#   'Open FDA': {},
#   'Product Type': 'Food',
#   'Event ID': '86882',
#   'Recalling Firm': 'Pacific Coast Producers',
#   'Address 1': '631 N Cluff Ave',
#   'Address 2': 'N/A',
#   'Postal Code': '95240-0756',
#   'Voluntary Mandated': 'Voluntary: Firm initiated',
#   'Initial Firm Notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'Distribution Pattern': 'US Distribution only',
#   'Recall Number': 'F-0164-2021',
#   'Product Description': 'Italian Style Tomato Paste in a 6 oz. (170g) metal can    Cases size varies - 12, 24 or 28 count.    Packaged under brand names of:  Kroger, Signature Select, Harris Teeter, Food Club, Essential Everyday, Raleys, Fareway.',
#   'Product Quantity': '31, 572 cases - total',
#   'Reason for Recall': 'Presence of metal shavings in tomato paste',
#   'Recall Initiation Date': '20201130',
#   'Center Classification Date': '20201208',
#   'Termination Date': '20210210',
#   'Report Date': '20201216',
#   'Code Info': '5TP1X 0P G253',
#   'More Code Info': nan}]

# %%
import pandas as pd
import plotly.express as px
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')  # Replace with your MongoDB URI if necessary
db = client['fda_recall_data']  # Database name
collection = db['recalls']  # Collection name

# Query MongoDB and load the data into a pandas DataFrame
recalls_cursor = collection.find({"State": {"$ne": ""}}, {"State": 1, "_id": 0})  # Fetch state data only
recalls_df = pd.DataFrame(list(recalls_cursor))

# Ensure the 'state' column exists and clean it
if 'State' in recalls_df.columns:
    recalls_df['State'] = recalls_df['State'].str.upper()  # Ensure all state abbreviations are uppercase

# Group by state and count the number of recalls per state
state_counts = recalls_df.groupby('State').size().reset_index(name='Count')

# Create Plotly choropleth map
fig = px.choropleth(
    state_counts, 
    locations='State', 
    locationmode="USA-states",  # Use state abbreviations for location matching
    color='Count', 
    color_continuous_scale="YlGnBu",  # Green-Blue color scale
    scope="usa",  # Limit the map to USA
    title="FDA Recalls by State"
)

# Customize the layout (optional)
fig.update_layout(
    geo=dict(
        lakecolor='rgb(255, 255, 255)'  # Set lake color to white
    )
)

# Save the figure as an interactive HTML file
fig.write_html("./output_data/fda_recalls_by_state.html")

# Optional: Show the figure in a notebook or browser (for testing or interactive use)
fig.show()

# %% [markdown]
# ** The code below will take about 5mins to run to create the HTML file since it is using Geopy Library to find latitude and longitude values from the 'City' and 'State' columns from the dataset **

# %%
import requests
import pandas as pd
import plotly.express as px
from pymongo import MongoClient
from datetime import datetime
from geopy.geocoders import Nominatim
import time

# Define the API endpoint and parameters
url = "https://api.fda.gov/food/enforcement.json?search=report_date:[20200101+TO+20241005]&limit=500"

# Send a GET request to the API
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    recalls = data.get('results', [])
    recall_df = pd.DataFrame(recalls)

    # Clean and rename columns
    clean_df = recall_df.rename(columns={
        "status": "Status", 
        "city": "City",
        "state": "State",
        "country": "Country",
        "classification": "Classification",
        "openfda": "Open FDA",
        "product_type": "Product Type",
        "event_id": "Event ID",
        "recalling_firm": "Recalling Firm",
        "address_1": "Address 1",
        "address_2": "Address 2",
        "postal_code": "Postal Code",
        "voluntary_mandated": "Voluntary Mandated",
        "initial_firm_notification": "Initial Firm Notification",
        "distribution_pattern": "Distribution Pattern",
        "recall_number": "Recall Number",
        "product_description": "Product Description",
        "product_quantity": "Product Quantity",
        "reason_for_recall": "Reason for Recall",
        "recall_initiation_date": "Recall Initiation Date",
        "center_classification_date": "Center Classification Date",
        "termination_date": "Termination Date",
        "report_date": "Report Date",
        "code_info": "Code Info",
        "more_code_info": "More Code Info",
    })

    # Convert DataFrame to dictionary format for MongoDB
    recall_records = clean_df.to_dict("records")

    # Connect to MongoDB and insert data (optional step if you want to store the data)
    client = MongoClient('mongodb://localhost:27017/')
    db = client['fda_recalls']
    collection = db['food_enforcement']
    collection.insert_many(recall_records)

    # Get unique cities and states for geocoding
    city_state_df = clean_df[['City', 'State']].drop_duplicates()

    # Geocoding cities to get latitude and longitude
    geolocator = Nominatim(user_agent="fda_recall_app")
    latitudes = []
    longitudes = []

    for index, row in city_state_df.iterrows():
        city_state = f"{row['City']}, {row['State']}, USA"
        try:
            location = geolocator.geocode(city_state)
            if location:
                latitudes.append(location.latitude)
                longitudes.append(location.longitude)
            else:
                latitudes.append(None)
                longitudes.append(None)
        except:
            latitudes.append(None)
            longitudes.append(None)
        time.sleep(1)  # Add delay to avoid overwhelming the geocoding API

    # Add latitude and longitude to the DataFrame
    city_state_df['Latitude'] = latitudes
    city_state_df['Longitude'] = longitudes

    # Filter out rows where geocoding failed
    city_state_df = city_state_df.dropna(subset=['Latitude', 'Longitude'])

    # Merge latitude and longitude back to the main DataFrame
    clean_df = pd.merge(clean_df, city_state_df, on=['City', 'State'], how='left')

    # Create a map with city markers using Plotly
    fig = px.scatter_mapbox(
        clean_df,
        lat="Latitude",
        lon="Longitude",
        hover_name="City",
        hover_data=["State", "Recall Number", "Reason for Recall"],
        zoom=3,
        height=1000,
        width=2000,
        title="FDA Recalls by City"
    )

    # Set mapbox style
    fig.update_layout(
        mapbox_style="open-street-map",
        margin={"r": 0, "t": 50, "l": 0, "b": 0}  # Adjusted margins for full-width display
    )

    # Show or save the figure as an interactive HTML file
    fig.write_html("./output_data/fda_recalls_by_city.html")
    print("Map with city markers saved as HTML file.")

    fig.show()
# Out:
# Map with city markers saved as HTML file.

# %%
print(recalls_df.columns)
# Out:
# Index(['State'], dtype='object')

# %%
print(recalls_df.head())
# Out:
#   State
# 0    CA
# 1    NY
# 2    CA
# 3    WY
# 4    AZ

# %%
import requests
import pandas as pd
import plotly.express as px

# Define the API endpoint and parameters
url = "https://api.fda.gov/food/enforcement.json?search=report_date:[20200101+TO+20241005]&limit=500"

# Send a GET request to the API
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    recalls = data.get('results', [])
    recall_df = pd.DataFrame(recalls)

    # Rename columns as you have done
    clean_df = recall_df.rename(columns={
        "status": "Status", 
        "city": "City",
        "state": "State",
        "country": "Country",
        "classification": "Classification",
        "openfda": "Open FDA",
        "product_type": "Product Type",
        "event_id": "Event ID",
        "recalling_firm": "Recalling Firm",
        "address_1": "Address 1",
        "address_2": "Address 2",
        "postal_code": "Postal Code",
        "voluntary_mandated": "Voluntary Mandated",
        "initial_firm_notification": "Initial Firm Notification",
        "distribution_pattern": "Distribution Pattern",
        "recall_number": "Recall Number",
        "product_description": "Product Description",
        "product_quantity": "Product Quantity",
        "reason_for_recall": "Reason for Recall",
        "recall_initiation_date": "Recall Initiation Date",
        "center_classification_date": "Center Classification Date",
        "termination_date": "Termination Date",
        "report_date": "Report Date",
        "code_info": "Code Info",
        "more_code_info": "More Code Info",
    })

    # Filter for United States recalls and group by state
    us_recall_df = clean_df[clean_df['Country'] == "United States"]
    state_counts = us_recall_df['State'].value_counts().reset_index()
    state_counts.columns = ['State', 'Count']

    # Create Plotly choropleth map
    fig = px.choropleth(
        state_counts, 
        locations='State', 
        locationmode="USA-states",  # This sets the matching on US state abbreviations
        color='Count', 
        color_continuous_scale="YlGnBu",  # Green-Blue color scale
        scope="usa",  # Scope limited to the US map
        title="FDA Recalls by State",
    )

    fig.update_layout(
        geo=dict(
            lakecolor='rgb(255, 255, 255)'
        )
    )

    # Save the figure as an interactive HTML file
    fig.write_html("./output_data/fda_recalls_by_state.html")

    print("Interactive HTML map saved as 'fda_recalls_by_state.html'.")

else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# Interactive HTML map saved as 'fda_recalls_by_state.html'.

# %%
import requests
import pandas as pd
import plotly.express as px

# Define the API endpoint and parameters
url = "https://api.fda.gov/food/enforcement.json?search=report_date:[20200101+TO+20241005]&limit=500"

# Send a GET request to the API
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    recalls = data.get('results', [])
    recall_df = pd.DataFrame(recalls)

    # Rename columns as you have done
    clean_df = recall_df.rename(columns={
        "status": "Status", 
        "city": "City",
        "state": "State",
        "country": "Country",
        "classification": "Classification",
        "openfda": "Open FDA",
        "product_type": "Product Type",
        "event_id": "Event ID",
        "recalling_firm": "Recalling Firm",
        "address_1": "Address 1",
        "address_2": "Address 2",
        "postal_code": "Postal Code",
        "voluntary_mandated": "Voluntary Mandated",
        "initial_firm_notification": "Initial Firm Notification",
        "distribution_pattern": "Distribution Pattern",
        "recall_number": "Recall Number",
        "product_description": "Product Description",
        "product_quantity": "Product Quantity",
        "reason_for_recall": "Reason for Recall",
        "recall_initiation_date": "Recall Initiation Date",
        "center_classification_date": "Center Classification Date",
        "termination_date": "Termination Date",
        "report_date": "Report Date",
        "code_info": "Code Info",
        "more_code_info": "More Code Info",
    })

    # Filter for United States recalls
    us_recall_df = clean_df[clean_df['Country'] == "United States"]

    # Get unique classifications
    classifications = us_recall_df['Classification'].unique()

    # Initialize an empty figure
    fig = px.choropleth(
        us_recall_df,
        locations='State',
        locationmode="USA-states",
        color='Classification',  # Initial color setting
        color_continuous_scale="YlGnBu",
        scope="usa",
        title="FDA Recalls by State",
    )

    # Update layout with dropdown functionality
    fig.update_layout(
        updatemenus=[
            {
                "buttons": [
                    {
                        "label": classification,
                        "method": "update",
                        "args": [
                            {
                                "visible": [classification == cl for cl in classifications],
                            },
                            {
                                "title": f"FDA Recalls by State: {classification}",
                            },
                        ],
                    } for classification in classifications
                ],
                "direction": "down",
                "showactive": True,
            },
        ],
    )

    fig.update_geos(fitbounds="locations", visible=False)
    fig.update_layout(
        geo=dict(
            lakecolor='rgb(255, 255, 255)'
        )
    )

    # Save the figure as an interactive HTML file
    fig.write_html("./output_data/fda_recalls_by_classification.html")

    print("Interactive HTML map saved as 'fda_recalls_by_classification.html'.")

else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# Interactive HTML map saved as 'fda_recalls_by_classification.html'.

# %%
state_counts
#print(clean_df.head())
# Out:
#    State  Count
# 0     CA     54
# 1     NY     48
# 2     MD     44
# 3     OH     42
# 4     IL     30
# 5     FL     28
# 6     GA     21
# 7     WA     19
# 8     OR     15
# 9     TX     15
# 10    NJ     14
# 11    PA     13
# 12    MN     12
# 13    MI     12
# 14    WI     11
# 15    NM      9
# 16    MA      9
# 17    IA      8
# 18    VA      8
# 19    UT      8
# 20    KS      8
# 21    ID      7
# 22    VT      7
# 23    NC      6
# 24    AZ      5
# 25    CO      5
# 26    WY      4
# 27    MO      4
# 28    CT      4
# 29    IN      4
# 30    NH      3
# 31    PR      2
# 32    SC      2
# 33    AR      2
# 34    AL      1
# 35    OK      1
# 36    DE      1
# 37    KY      1
# 38    MS      1
# 39    NE      1
# 40    NV      1
# 41    ND      1

# %%
us_recall_df = clean_df[clean_df['Country'] == "United States"]

# %%
us_recall_df.to_csv('output_data/fda_food_enforcement_data.csv', index=False)
